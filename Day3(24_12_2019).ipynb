# %% [markdown]
# #python programming
# ##python programming
# ###python programming
# ####python programming
# #####python programming

# %% [markdown]
# 1. a
# 2. b
# 3. c
#   1. d
#   2. e
#   3. f

# %% [markdown]
# [python](http://ct3.gitam.edu/attendance/student/)

# %% [markdown]
# ![image](https://i.udemycdn.com/course/750x422/1817082_cf8a_9.jpg)

# %% [markdown]
# -  abc
# -  def

# %%
print("hello world!!!")
# Out:
# hello world!!!

# %%
a=10
b=20
print(type(a),type(b))
# Out:
# <class 'int'> <class 'int'>

# %%
a=int(input("enter a value"))
b=int(input("enter b value"))
print(a+b)
# Out:
# enter a value10
# enter b value20
# 30

# %%
a=input("enter a")
b=int(input("enter b"))
print("my name is",a,end=" ")
print("and age is",b)
# Out:
# enter apreeti
# enter b25
# my name is preeti and age is 25

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               def                 if                  raise
# None                del                 import              return
# True                elif                in                  try
# and                 else                is                  while
# as                  except              lambda              with
# assert              finally             nonlocal            yield
# break               for                 not
# class               from                or
# continue            global              pass
